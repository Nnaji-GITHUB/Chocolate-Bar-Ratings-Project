# %% [markdown]
# Case Study Project - Chocolate Bar Ratings
#
# Table of Contents
#
# 1. Import libraries
#
# 2. Import Data
#
# 3. Data Wrangling
#
#    Change city name to Country
#
# 4. Data Cleaning nad Consistency Check
#
#    check for missing data
#
#    check for duplicates
#
#    check for mixed data types

# %% [markdown]
# # Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# Using path method to import my dataset
"C:\Users\Peter\Desktop\Data Analytics documents\Data Immersion\Achievement 6"

# %%
path = r"C:\Users\Peter\Desktop\Data Analytics documents\Data Immersion\Achievement 6"

# %%
path
# Out:
# 'C:\\Users\\Peter\\Desktop\\Data Analytics documents\\Data Immersion\\Achievement 6'

# %%
# imported the dataset
df = pd.read_csv(os.path.join(path, 'Project','Chocolate_Bar_ratings.csv'), index_col = False)

# %%
df.head(30)
# Out:
#    Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                    A. Morin                       Agua Grande  1876
# 1                    A. Morin                             Kpime  1676
# 2                    A. Morin                            Atsane  1676
# 3                    A. Morin                             Akata  1680
# 4                    A. Morin                            Quilla  1704
# 5                    A. Morin                          Carenero  1315
# 6                    A. Morin                              Cuba  1315
# 7                    A. Morin                      Sur del Lago  1315
# 8                    A. Morin                    Puerto Cabello  1319
# 9                    A. Morin                           Pablino  1319
# 10                   A. Morin                            Panama  1011
# 11                   A. Morin                        Madagascar  1011
# ...

# %%
# check the shape of the dataframe
df.shape
# Out:
# (1795, 9)

# %%
# check the information of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Company
# (Maker-if known)         1795 non-null   object
#  1   Specific Bean Origin
# or Bar Name  1795 non-null   object
#  2   REF                               1795 non-null   int64
#  3   Review
# Date                       1795 non-null   int64
#  4   Cocoa
# Percent                     1795 non-null   object
#  5   Company
# Location                  1795 non-null   object
#  6   Rating                            1795 non-null   float64
#  7   Bean
# Type                         1794 non-null   object
#  8   Broad Bean
# Origin                 1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
df.describe()
# Out:
#                REF  Review\nDate       Rating
# count  1795.000000   1795.000000  1795.000000
# mean   1035.904735   2012.325348     3.185933
# std     552.886365      2.927210     0.478062
# min       5.000000   2006.000000     1.000000
# 25%     576.000000   2010.000000     2.875000
# 50%    1069.000000   2013.000000     3.250000
# 75%    1502.000000   2015.000000     3.500000
# max    1952.000000   2017.000000     5.000000

# %% [markdown]
# # Performing Data Wrangling

# %%
# replacing the City name to Country
df['Company\nLocation'].replace('Amsterdam','Netherlands',inplace=True)

# %% [markdown]
# # Data Cleaning and Consistency Check

# %%
#check for missing values
df.isnull().sum()
# Out:
# Company \n(Maker-if known)           0
# Specific Bean Origin\nor Bar Name    0
# REF                                  0
# Review\nDate                         0
# Cocoa\nPercent                       0
# Company\nLocation                    0
# Rating                               0
# Bean\nType                           1
# Broad Bean\nOrigin                   1
# dtype: int64

# %%
# drop the missing values
df_clean = df.dropna()

# %%
# check the shape of the clean dataframe
df_clean.shape
# Out:
# (1793, 9)

# %%
#check for missing values
df_clean.isnull().sum()
# Out:
# Company \n(Maker-if known)           0
# Specific Bean Origin\nor Bar Name    0
# REF                                  0
# Review\nDate                         0
# Cocoa\nPercent                       0
# Company\nLocation                    0
# Rating                               0
# Bean\nType                           0
# Broad Bean\nOrigin                   0
# dtype: int64

# %%
# checking at the Statistic again
df_clean.describe()
# Out:
#                REF  Review\nDate       Rating
# count  1793.000000   1793.000000  1793.000000
# mean   1036.126046   2012.326269     3.185862
# std     553.128742      2.928666     0.477668
# min       5.000000   2006.000000     1.000000
# 25%     576.000000   2010.000000     3.000000
# 50%    1073.000000   2013.000000     3.250000
# 75%    1502.000000   2015.000000     3.500000
# max    1952.000000   2017.000000     5.000000

# %%
# check for duplicates
df_clean_dups = df_clean[df_clean.duplicated()]

# %%
df_clean_dups
# Out:
# Empty DataFrame
# Columns: [Company
# (Maker-if known), Specific Bean Origin
# or Bar Name, REF, Review
# Date, Cocoa
# Percent, Company
# Location, Rating, Bean
# Type, Broad Bean
# Origin]
# Index: []

# %%
# check for mixed data type
for col in df_clean.columns.tolist():
  weird = (df_clean[[col]].applymap(type) != df_clean[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_clean[weird]) > 0:
    print (col)

# %%
# check for the shape of the cleaned dataframe
df_clean.shape
# Out:
# (1793, 9)

# %%
# importing my clean dataframe
df_clean.to_csv(os.path.join(path,'Project','Chocolate_Bar_ratings_cleaned.csv'))
